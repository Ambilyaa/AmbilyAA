# %%
import numpy as np                                     # importing numpy library
import pandas as pd                                    # importing pandas library
import matplotlib.pyplot as plt                        # importing matplotlib library
import seaborn as sns                                  # importing seaborn library

# %%
data=pd.read_csv(r"C:\Users\Amby\Downloads\datsets\StudentsPerformance.csv") # loading students performance dataset

# %%
data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group C            some high school  free/reduced
# 1    female        group B                 high school  free/reduced
# 2    female        group B            some high school  free/reduced
# 3    female        group B                some college      standard
# 4    female        group C                some college  free/reduced
# ..      ...            ...                         ...           ...
# 995    male        group E                some college      standard
# 996    male        group A                some college      standard
# 997    male        group D                some college      standard
# 998    male        group E          associate's degree  free/reduced
# 999    male        group E           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group C            some high school  free/reduced
# 1  female        group B                 high school  free/reduced
# 2  female        group B            some high school  free/reduced
# 3  female        group B                some college      standard
# 4  female        group C                some college  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none           0             17             10
# 1                    none           8             24             23
# 2                    none          18             32             28
# 3                    none          11             38             32
# 4                    none          22             39             33

# %% [markdown]
# **_Q.1. Find out how many males and females participated in the test._**

# %%
data['gender'].value_counts()                # this function gives the count of unique values in the column gender
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %%
sns.countplot(x='gender',data=data)                     # plotting countplot to show the counts of females and males
plt.title("Count of Females and Males participated in the test") 
plt.show()

# %% [markdown]
#  The no: of females and males participated in the test are 518 and 482 respectively.

# %% [markdown]
# **_Q.2. What do you think about the student's parental level of education?_**

# %%
data['parental level of education'].value_counts() #finding all the unique values and their counts in parental level of education
# Out:
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: parental level of education, dtype: int64

# %%
sns.countplot(x='parental level of education',data=data)       # plotting countplot on parental level of education 
plt.xticks(rotation=45)
plt.title("Parental level of education of the students ")
plt.show()

# %%
sns.boxplot(x='parental level of education',y='math score',data=data)            #plotting boxplot
plt.xticks(rotation=45)                                                          # rotating xlabels to 45 degrees
plt.title("Parental level of education vs Math score of the students ")          # giving title
plt.show()

# %%
sns.boxplot(x='parental level of education',y='reading score',data=data)
plt.xticks(rotation=45)
plt.title("Parental level of education vs Reading score of the students ")
plt.show()

# %%
sns.boxplot(x='parental level of education',y='writing score',data=data)
plt.xticks(rotation=45)
plt.title("Parental level of education vs Writing score of the students ")
plt.show()

# %% [markdown]
# The above boxplots shows that the parental education of the students have an impact on the student's overall performance. The higher the parental education level, it is better the students score.
# The students whose parents with masters degree have scored highest for all the three subjects.

# %% [markdown]
# **_Q.3(A). Who scores the most on average for math, reading and writing based on gender?_**

# %%
mean_gen=data.groupby('gender')[['math score','reading score',"writing score"]].mean() #finding column-wise mean  
mean_gen
# Out:
#         math score  reading score  writing score
# gender
# female   63.376448      72.590734      72.467181
# male     68.821577      65.545643      63.446058

# %%
plt.figure(figsize=(15,6))                       
mean_gen.plot.bar()                                         #plotting bar graph 
plt.title("Gender-wise Mean of scores")
plt.show()

# %% [markdown]
# By finding the mean of all the given scores based on gender, male students score the most for Mathematics and female students score the most for reading and writing.

# %% [markdown]
# **_Q.3(B). Who scores the most on average for math, reading and writing based on test preparation course?_**

# %%
mean_tp=data.groupby('test preparation course')[['math score','reading score',"writing score"]].mean()
mean_tp
# Out:
#                          math score  reading score  writing score
# test preparation course
# completed                  69.96648      74.175978      74.684358
# none                       63.78972      66.417445      64.457944

# %%
mean_tp.plot.bar()
plt.title('Mean of scores vs Test Preparation course')
plt.show()

# %% [markdown]
# By finding the mean of all the given scores based on test preparation course, those students who completed the test preparation course score the most for Mathematics, reading and writing.

# %% [markdown]
# **_Q.4(A). What do you think about the scoring variation for math, reading and writing based on gender?_**

# %%
var_gender=data.groupby('gender')[['math score','reading score',"writing score"]].var()
var_gender
# Out:
#         math score  reading score  writing score
# gender
# female  256.958593     207.677438     220.369327
# male    211.889097     200.211010     202.413924

# %% [markdown]
# The dispersion of scores for females is high when compared to males.

# %%
sns.boxplot(x='gender',y='math score',data=data)
plt.title("Gender vs Math score of the students ")
plt.show()

# %%
sns.boxplot(x='gender',y='reading score',data=data)
plt.title("Gender vs Reading score of the students ")
plt.show()

# %%
sns.boxplot(x='gender',y='writing score',data=data)
plt.title("Gender vs Writing score of the students ")
plt.show()

# %% [markdown]
# Based on gender, female students shows maximum variance in the scores for all subjects. When compared to males, female student shows more outliers in the above boxplots.

# %% [markdown]
# **_Q.4(B). What do you think about the scoring variation for math, reading and writing based on test preparation course?_**

# %%
var_tp=data.groupby('test preparation course')[['math score','reading score',"writing score"]].var()
var_tp
# Out:
#                          math score  reading score  writing score
# test preparation course
# completed                210.884027     183.265864     175.202612
# none                     246.668662     213.419851     226.251739

# %%
sns.boxplot(x='test preparation course',y='math score',data=data)
plt.title("Test Preparation Course vs Math score of the students ")
plt.show()

# %%
sns.boxplot(x='test preparation course',y='reading score',data=data)
plt.title("Test Preparation Course vs Reading score of the students ")
plt.show()

# %%
sns.boxplot(x='test preparation course',y='writing score',data=data)
plt.title("Test Preparation Course vs Writing score of the students ")
plt.show()

# %% [markdown]
# From the above boxplots, it is clear that the students who had completed the course scored better marks than those who didnot complete. We can see variance level is high for the students who didnot complete the course(have scored lowest marks).

# %% [markdown]
# **_Q.5. The management needs your help to give bonus points to the top 25% of students based on their math score, so how will you help the management to achieve this._**

# %%
math_25pt=data['math score'].quantile(0.25)

# %%
math_top=data[data['math score']>math_25pt]

# %%
math_top=math_top.sort_values(by='math score',ascending=False)

# %%
math_top.head(250)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 999    male        group E           bachelor's degree      standard
# 996    male        group A                some college      standard
# 516  female        group E           bachelor's degree      standard
# 517  female        group E          associate's degree      standard
# 515  female        group E                some college      standard
# ..      ...            ...                         ...           ...
# 856    male        group E            some high school      standard
# 854    male        group D            some high school      standard
# 853    male        group D          associate's degree  free/reduced
# 852    male        group D                some college  free/reduced
# 416  female        group B           bachelor's degree  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# Using the quantile function, calculated the 25th percentile of the math score. Then found the students whose math scores are above 25th percentile score.Then sorted the top math students based on their math score in descending order. Here,the total no: of students in the dataset is 1000 and its 25% is 250. Finally printed the top 25% of students based on their math score.
